# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Reading the file

# %%
db = pd.read_csv(r'C:\Users\User\Desktop\data project\food\ifood_df.csv')
db.columns
db.head()
# Out:
#    Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0   58138        0         0       58       635         88              546
# 1   46344        1         1       38        11          1                6
# 2   71613        0         0       26       426         49              127
# 3   26646        1         0       26        11          4               20
# 4   58293        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0              172                88            88                  3
# 1                2                 1             6                  2
# 2              111                21            42                  1
# 3               10                 3             5                  2
# 4               46                27            15                  5
#
#    NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# ...

# %%
db.nunique()
# Out:
# Income                 1963
# Kidhome                   3
# Teenhome                  3
# Recency                 100
# MntWines                775
# MntFruits               158
# MntMeatProducts         551
# MntFishProducts         182
# MntSweetProducts        176
# MntGoldProds            212
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      13
# NumStorePurchases        14
# NumWebVisitsMonth        16
# Complain                  2
# Response                  2
# Age                      56
# MntTotal                897
# MntRegularProds         974
# dtype: int64

# %%
db.describe().transpose()
# Out:
#                       count          mean           std     min      25%  \
# Income               2205.0  51622.094785  20713.063826  1730.0  35196.0
# Kidhome              2205.0      0.442177      0.537132     0.0      0.0
# Teenhome             2205.0      0.506576      0.544380     0.0      0.0
# Recency              2205.0     49.009070     28.932111     0.0     24.0
# MntWines             2205.0    306.164626    337.493839     0.0     24.0
# MntFruits            2205.0     26.403175     39.784484     0.0      2.0
# MntMeatProducts      2205.0    165.312018    217.784507     0.0     16.0
# MntFishProducts      2205.0     37.756463     54.824635     0.0      3.0
# MntSweetProducts     2205.0     27.128345     41.130468     0.0      1.0
# MntGoldProds         2205.0     44.057143     51.736211     0.0      9.0
# NumDealsPurchases    2205.0      2.318367      1.886107     0.0      1.0
# NumWebPurchases      2205.0      4.100680      2.737424     0.0      2.0
# ...

# %%
db.shape
# Out:
# (2205, 20)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Income               2205 non-null   int64
#  1   Kidhome              2205 non-null   int64
#  2   Teenhome             2205 non-null   int64
#  3   Recency              2205 non-null   int64
#  4   MntWines             2205 non-null   int64
#  5   MntFruits            2205 non-null   int64
#  6   MntMeatProducts      2205 non-null   int64
#  7   MntFishProducts      2205 non-null   int64
#  8   MntSweetProducts     2205 non-null   int64
#  9   MntGoldProds         2205 non-null   int64
#  10  NumDealsPurchases    2205 non-null   int64
#  11  NumWebPurchases      2205 non-null   int64
#  12  NumCatalogPurchases  2205 non-null   int64
#  13  NumStorePurchases    2205 non-null   int64
#  14  NumWebVisitsMonth    2205 non-null   int64
# ...

# %% [markdown]
# Data Cleaning

# %%
db.isnull().sum()
# Out:
# Income                 0
# Kidhome                0
# Teenhome               0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Complain               0
# Response               0
# Age                    0
# MntTotal               0
# MntRegularProds        0
# dtype: int64

# %%
db.shape
# Out:
# (2205, 20)

# %% [markdown]
# Data Visulization

# %%
plt.figure(figsize=(19,10))
relation = db.corr()
sns.heatmap(relation, cmap = 'rocket', annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# the avg income of a customer

# %%
average = round(int(db['Income'].mean()),0)
print(average)
# Out:
# 51622

# %% [markdown]
# The number of customers with kids

# %%
db['Kidhome'].value_counts()
# Out:
# 0    1276
# 1     883
# 2      46
# Name: Kidhome, dtype: int64

# %%
plt.title("Numbers of customers with kids")
sns.countplot(data=db, x='Kidhome')
# Out:
# <AxesSubplot:title={'center':'Numbers of customers with kids'}, xlabel='Kidhome', ylabel='count'>

# %% [markdown]
# Over 1200 customers dont have kids in their homes

# %% [markdown]
# The number of customers with Teens

# %%
db['Teenhome'].value_counts()
# Out:
# 0    1139
# 1    1015
# 2      51
# Name: Teenhome, dtype: int64

# %%
plt.title("Numbers of customers with Teens")
sns.countplot(data=db, x='Teenhome')
# Out:
# <AxesSubplot:title={'center':'Numbers of customers with Teens'}, xlabel='Teenhome', ylabel='count'>

# %% [markdown]
# There are over 1000 customers who dont have teens in there homes

# %% [markdown]
# The number of customers that have both teen and kids

# %%
T_K = db[(db['Teenhome'] > 0) & (db['Kidhome'] > 0)]
count = T_K.shape[0]
print("{} customers has both kids and teenagers".format(count))
# Out:
# 418 customers has both kids and teenagers

# %% [markdown]
# The average age of the customers

# %%
average1 = round(int(db['Age'].mean()),0)
print(average1)
# Out:
# 51

# %% [markdown]
# Data Visulization

# %% [markdown]
# Numbers of purchases made with th discount

# %%
plt.title("Numbers of purchases made with discount")
sns.countplot(data=db, x='NumDealsPurchases')
# Out:
# <AxesSubplot:title={'center':'Numbers of purchases made with discount'}, xlabel='NumDealsPurchases', ylabel='count'>

# %% [markdown]
# Number of purchases made with the website

# %%
plt.title("Numbers of purchases made with the website")
sns.countplot(data=db, x='NumWebPurchases')
# Out:
# <AxesSubplot:title={'center':'Numbers of purchases made with the website'}, xlabel='NumWebPurchases', ylabel='count'>

# %% [markdown]
# How many people visits the website permonth?

# %%
plt.title("Numbers of visits made on the website permonth")
sns.countplot(data=db, x='NumWebVisitsMonth')
# Out:
# <AxesSubplot:title={'center':'Numbers of visits made on the website permonth'}, xlabel='NumWebVisitsMonth', ylabel='count'>

# %% [markdown]
# a total number of 7 visits per_month by each customers

# %% [markdown]
# Number of purchases made with the catalog

# %%
plt.title("Numbers of purchases made with the catalog")
sns.countplot(data=db, x='NumCatalogPurchases')
# Out:
# <AxesSubplot:title={'center':'Numbers of purchases made with the catalog'}, xlabel='NumCatalogPurchases', ylabel='count'>

# %% [markdown]
# A few number of people makes purchases with the catalog

# %% [markdown]
# Number of people that pefer to go directly to the store to make purchases

# %%
plt.title("Numbers of purchases made directly in the store")
sns.countplot(data=db, x='NumStorePurchases')
# Out:
# <AxesSubplot:title={'center':'Numbers of purchases made directly in the store'}, xlabel='NumStorePurchases', ylabel='count'>

# %%
C_W= db[(db['NumWebPurchases'] > 0) & (db['NumCatalogPurchases'] > 0)]
count1 = C_W.shape[0]
print("{} customers that makes purchases using both catalog and website".format(count1))
# Out:
# 1625 customers that makes purchases using both catalog and website

# %%
db.describe().transpose()
# Out:
#                       count          mean           std     min      25%  \
# Income               2205.0  51622.094785  20713.063826  1730.0  35196.0
# Kidhome              2205.0      0.442177      0.537132     0.0      0.0
# Teenhome             2205.0      0.506576      0.544380     0.0      0.0
# Recency              2205.0     49.009070     28.932111     0.0     24.0
# MntWines             2205.0    306.164626    337.493839     0.0     24.0
# MntFruits            2205.0     26.403175     39.784484     0.0      2.0
# MntMeatProducts      2205.0    165.312018    217.784507     0.0     16.0
# MntFishProducts      2205.0     37.756463     54.824635     0.0      3.0
# MntSweetProducts     2205.0     27.128345     41.130468     0.0      1.0
# MntGoldProds         2205.0     44.057143     51.736211     0.0      9.0
# NumDealsPurchases    2205.0      2.318367      1.886107     0.0      1.0
# NumWebPurchases      2205.0      4.100680      2.737424     0.0      2.0
# ...

# %%
db['Complain'].value_counts()
# Out:
# 0    2185
# 1      20
# Name: Complain, dtype: int64

# %%
complains = db['Complain'].value_counts()[1]
print ("There are {} complains laid by the customers".format(complains))
# Out:
# There are 20 complains laid by the customers
